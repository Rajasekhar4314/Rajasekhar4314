# %%
# operators

# %%
a=10
b=20
if a==10 and b==20:
    print('valid statement')
# Out:
# valid statement

# %%
a=10
b=20
if a==10 and b==20:
    print('valid statement')
else:
    print('not valid')
# Out:
# valid statement

# %%
a==10
# Out:
# True

# %%
b==20
# Out:
# True

# %%
a==10 and b<20
# Out:
# False

# %%
a=10
b=20
if a==10 and b>20:
    print('valid statement')
elif a==10 and b<=20:
    print('statement valid inside elif')
else:
    print('not valid')
# Out:
# statement valid inside elif

# %%
a=10
b=20
if a==10 or b>20:
    print('valid statement')
elif a==10 and b<=20:
    print('statement valid inside elif')
else:
    print('not valid')
# Out:
# valid statement

# %%
a=input('enter first name')
b=input("enter last name")
if a=='raja' and b=='sekhar':
    print("valid")
else:
    print("not valiud")
# Out:
# enter first nameraja
# enter last namesekhar
# valid

# %%
if a==10:
    print('valid')

# %%
initial_speed = 0
final_speed = 10
while initial_speed<final_speed:
    print('speed')

# %%
initial_speed = 0
final_speed = 20
count = 1
while initial_speed<final_speed:
    print('this is my speed')
    count = count+1
    if count == 10:
        break
# Out:
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed

# %%
initial_speed = 0
final_speed = 20
count = 1
while initial_speed<final_speed:
    print('this is my speed')
    count = count+1
    if count == 10:
        break
# Out:
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed

# %%
initial_speed = 0
final_speed = 10
count = 1
while initial_speed<final_speed:
    print('this is my speed')
    count = count+1
    if count == 5:
        break
# Out:
# this is my speed
# this is my speed
# this is my speed
# this is my speed

# %%
i=1
j=5
while i<j:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
